# %% [markdown]
# # **Theoretical Overview of Docker and Containerization**

# %% [markdown]
# **Name : Chirag Kailashbhai Rawat**

# %% [markdown]
# 1. **Install Docker and create Dockerfiles to containerize applications?**

# %% [markdown]
# ![pwr.png](data:image/png;base64,...)

# %% [markdown]
# ![hello.png](data:image/png;base64,...)
